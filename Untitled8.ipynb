# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model,load_model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt

# %%
cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !unzip archive.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Rock-Paper-Scissors/train/paper/paper04-118.png
#   inflating: Rock-Paper-Scissors/train/paper/paper04-119.png
#   inflating: Rock-Paper-Scissors/train/paper/paper05-000.png
#   inflating: Rock-Paper-Scissors/train/paper/paper05-001.png
#   inflating: Rock-Paper-Scissors/train/paper/paper05-002.png
#   inflating: Rock-Paper-Scissors/train/paper/paper05-003.png
#   inflating: Rock-Paper-Scissors/train/paper/paper05-004.png
#   inflating: Rock-Paper-Scissors/train/paper/paper05-005.png
#   inflating: Rock-Paper-Scissors/train/paper/paper05-006.png
#   inflating: Rock-Paper-Scissors/train/paper/paper05-007.png
#   inflating: Rock-Paper-Scissors/train/paper/paper05-008.png
#   inflating: Rock-Paper-Scissors/train/paper/paper05-009.png
#   inflating: Rock-Paper-Scissors/train/paper/paper05-010.png
#   inflating: Rock-Paper-Scissors/train/paper/paper05-011.png
#   inflating: Rock-Paper-Scissors/train/paper/paper05-012.png
# ...

# %%
train_path = '/content/drive/MyDrive/Rock-Paper-Scissors/train'
valid_path = '/content/drive/MyDrive/Rock-Paper-Scissors/test'

# %%
vgg = VGG16(input_shape=(224,224,3), weights='imagenet', include_top=False)
# Out:
# ...
# 58892288/58889256 [==============================] - 2s 0us/step

# %%
for layer in vgg.layers:
  layer.trainable = False

# %%
folders = glob('/content/drive/MyDrive/Rock-Paper-Scissors/test/*')

# %%
x= Flatten()(vgg.output)

# %%
predictions = Dense(len(folders), activation='softmax')(x)

# %%
model = Model(inputs=vgg.input, outputs=predictions)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/Rock-Paper-Scissors/train',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')
# Out:
# Found 2520 images belonging to 3 classes.

# %%
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/Rock-Paper-Scissors/test',
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 372 images belonging to 3 classes.

# %%
r = model.fit(
  training_set,
  validation_data=test_set,
  epochs=5,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set))
# Out:
# Epoch 1/5
# 79/79 [==============================] - 1034s 13s/step - loss: 0.7493 - accuracy: 0.7800 - val_loss: 0.1553 - val_accuracy: 0.9651
# Epoch 2/5
# 79/79 [==============================] - 37s 472ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.1872 - val_accuracy: 0.9462
# Epoch 3/5
# 79/79 [==============================] - 38s 479ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.1474 - val_accuracy: 0.9651
# Epoch 4/5
# 79/79 [==============================] - 37s 473ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9409
# Epoch 5/5
# 79/79 [==============================] - 38s 476ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.1590 - val_accuracy: 0.9597

# %%
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')
